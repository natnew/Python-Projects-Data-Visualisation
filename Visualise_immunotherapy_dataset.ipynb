# %% [markdown]
# <a href="https://colab.research.google.com/github/natnew/Python-Projects-Data-Visualisation/blob/main/Visualise_immunotherapy_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load Libraries

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
import numpy as np

# %% [markdown]
# # Load and Examine Data

# %%
# Path of the file to read
immuno_filepath = ('immunotherapy.csv')

# Read the file into a variable iris_data
#immuno_data = pd.read_csv(immuno_filepath, index_col="Id")
immuno_data = pd.read_csv(immuno_filepath)

# Print the first 5 rows of the data
immuno_data.head(45)
# Out:
#     Unnamed: 0  sex   age  ...  Area  induration_diameter  Result_of_Treatment
# 0            1    1  22.0  ...    51                   50                    1
# 1            2    1  15.0  ...   900                   70                    1
# 2            3    1  16.0  ...   100                   25                    1
# 3            4    1  27.0  ...    80                   30                    1
# 4            5    1  20.0  ...    45                    8                    1
# 5            6    1  15.0  ...    84                    7                    1
# 6            7    1  35.0  ...     8                    6                    1
# 7            8    2  28.0  ...     9                    2                    1
# 8            9    2  19.0  ...   225                    8                    1
# 9           10    2   NaN  ...    35                    5                    0
# 10          11    2  33.0  ...    30                    3                    1
# ...

# %%
immuno_data.info

# %%
immuno_data.describe

# %%
immuno_data.isnull

# %%
immuno_data.isnull ().sum ()
# Out:
# Unnamed: 0             0
# sex                    0
# age                    4
# Time                   0
# Number_of_Warts        7
# Type                   3
# Area                   0
# induration_diameter    0
# Result_of_Treatment    0
# dtype: int64

# %%
immuno_data.shape
# Out:
# (90, 9)

# %% [markdown]
# # Replace Missing Values

# %%
# Drop the missing values (NAN)
immuno_data.dropna(inplace = True)

# %%
immuno_data.head(45)
# Out:
#     Unnamed: 0  sex   age  ...  induration_diameter  Result_of_Treatment  small
# 0            1    1  22.0  ...                 True                    1   True
# 2            3    1  16.0  ...                 True                    1   True
# 3            4    1  27.0  ...                 True                    1   True
# 4            5    1  20.0  ...                 True                    1   True
# 5            6    1  15.0  ...                 True                    1   True
# 6            7    1  35.0  ...                 True                    1   True
# 7            8    2  28.0  ...                 True                    1   True
# 8            9    2  19.0  ...                 True                    1   True
# 10          11    2  33.0  ...                 True                    1   True
# 11          12    2  17.0  ...                 True                    1   True
# 12          13    2  15.0  ...                 True                    0   True
# ...

# %%
immuno_data['small'] =  np.where(immuno_data['induration_diameter']<20, True, False)

# %%
immuno_data['medium'] =  np.where(immuno_data['induration_diameter']!=['small'] and immuno_data['induration_diameter']!=['large'], True, False)

# %%
immuno_data['large'] =  np.where(immuno_data['induration_diameter']>50, True, False)

# %%
immuno_data['newFeature'] = np.where(immuno_data['induration_diameter']<20, "SMALL",np.where(immuno_data['induration_diameter']>50, "LARGE"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-3ededc9b8a00> in <module>()
# ----> 1 immuno_data['newFeature'] = np.where(immuno_data['small']<20, "SMALL",np.where(immuno_data['large']>50, "LARGE"))
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ValueError: either both or neither of x and y should be given

# %%
immuno_data.head()
# Out:
#    Unnamed: 0  sex   age  ...  Result_of_Treatment  small  large
# 0           1    1  22.0  ...                    1   True  False
# 2           3    1  16.0  ...                    1   True  False
# 3           4    1  27.0  ...                    1   True  False
# 4           5    1  20.0  ...                    1   True  False
# 5           6    1  15.0  ...                    1   True  False
#
# [5 rows x 11 columns]

# %%
immuno_data['small'] = immuno_data['induration_diameter'].map(english_to_multiple)
immuno_data

# %% [markdown]
# # Plot a histogram

# %%
# Histogram 
sns.distplot(a=iris_data['Petal Length (cm)'], kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Plot a Density Plot

# %%
# KDE plot 
sns.kdeplot(data=iris_data['Petal Length (cm)'], shade=True)

# %% [markdown]
# # Plot 2D KDE Plot

# %%
# 2D KDE plot
sns.jointplot(x=iris_data['Petal Length (cm)'], y=iris_data['Sepal Width (cm)'], kind="kde")

# %% [markdown]
# # Plot Colour coded plots

# %%
# Paths of the files to read
iris_set_filepath = ('iris.csv')
iris_ver_filepath = ('iris_versicolor.csv')
iris_vir_filepath = ('iris_virginica.csv')

# Read the files into variables 
iris_set_data = pd.read_csv(iris_set_filepath, index_col="Id")
iris_ver_data = pd.read_csv(iris_ver_filepath, index_col="Id")
iris_vir_data = pd.read_csv(iris_vir_filepath, index_col="Id")

# Print the first 5 rows of the Iris versicolor data
iris_ver_data.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  ...  Petal Width (cm)          Species
# Id                                       ...
# 51                7.0               3.2  ...               1.4  Iris-versicolor
# 52                6.4               3.2  ...               1.5  Iris-versicolor
# 53                6.9               3.1  ...               1.5  Iris-versicolor
# 54                5.5               2.3  ...               1.3  Iris-versicolor
# 55                6.5               2.8  ...               1.5  Iris-versicolor
#
# [5 rows x 5 columns]

# %%
# Histograms for each species
sns.distplot(a=iris_set_data['Petal Length (cm)'], label="Iris-setosa", kde=False)
sns.distplot(a=iris_ver_data['Petal Length (cm)'], label="Iris-versicolor", kde=False)
sns.distplot(a=iris_vir_data['Petal Length (cm)'], label="Iris-virginica", kde=False)

# Add title
plt.title("Histogram of Petal Lengths, by Species")

# Force legend to appear
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# KDE plots for each species
sns.kdeplot(data=iris_set_data['Petal Length (cm)'], label="Iris-setosa", shade=True)
sns.kdeplot(data=iris_ver_data['Petal Length (cm)'], label="Iris-versicolor", shade=True)
sns.kdeplot(data=iris_vir_data['Petal Length (cm)'], label="Iris-virginica", shade=True)

# Add title
plt.title("Distribution of Petal Lengths, by Species")
# Out:
# Text(0.5, 1.0, 'Distribution of Petal Lengths, by Species')
